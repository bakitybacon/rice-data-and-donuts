# %% [markdown]
# ### Aggregation of Digital Scholarship Archive File Data
#
# The following code uses the REST API provided by Rice's Digital Scholarship Archive (https://scholarship.rice.edu/rest) to aggregate statistics for file views present in the archive by community and collection.

# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
def get_community(jsonroot, name):
    """
    Recursively find a community in dictionary jsonroot 
    with the given name.
    Returns None if no match is found.
    """
    community = None
    for subcommunity in jsonroot['community']:
        if subcommunity['name'] == name:
            return subcommunity
        subsearch = get_community(subcommunity, name)
        if subsearch:
            return subsearch
        
    return None

# %%
def get_all_collections(jsonroot):
    """
    Recursively find all collections in dictionary jsonroot.
    Returns a dataframe with columns id, name, and handle.
    """
    ids = []
    names = []
    handles = []
    
    for collection in jsonroot['collection']:
        ids.append(collection['id'])
        names.append(collection['name'])
        handles.append(collection['handle'])
        
    collections = pd.DataFrame({'id': ids, 'name': names, 'handle': handles})
    
    for subcommunity in jsonroot['community']:
        subframe = get_all_collections(subcommunity)
        collections = pd.concat([collections, subframe], ignore_index=True)
    
    return collections

# %% [markdown]
# Step 1: Find the community of interest.

# %%
# the hierarchy page contains the entire tree-like structure of the Digital Scholarship Archive,
#   where a community is an interior node and a collection is a leaf with associated file data.
hierarchyurl = 'https://scholarship.rice.edu/rest/hierarchy'

response = requests.get(hierarchyurl)
data = json.loads(response.text)
communitydata = get_community(data, 'TIMEA - Travelers in the Middle East Archive')

# %% [markdown]
# Step 2: Extract all collections.

# %%
allcollections = get_all_collections(communitydata)
allcollections['url'] = 'https://scholarship.rice.edu/rest/collections/' + allcollections['id'] + '/items'

handles = []
collectionnames = []
collectionurls = []

for idx, row in allcollections.iterrows():
    url = row['url']
    
    response = requests.get(url)
    jresponse = json.loads(response.text)

    # annoyingly, there are collections with no items.
    #  this test will throw out such collections.
    if len(jresponse) == 0:
        continue

    data = jresponse[0]
    handles.append(data['handle'].split("/")[1])
    collectionnames.append(row['name'])
    collectionurls.append(url)
    
allcollections = pd.DataFrame({'handle': handles, 'collectionname': collectionnames, 'link': collectionurls})
allcollections
# Out:
#    handle                   collectionname  \
# 0    9305  TIMEA Historical Maps and Plans
# 1   13086                   TIMEA Research
# 2  103799                      TIMEA Texts
# 3   10329          TIMEA Visual Materials
#
#                                                 link
# 0  https://scholarship.rice.edu/rest/collections/...
# 1  https://scholarship.rice.edu/rest/collections/...
# 2  https://scholarship.rice.edu/rest/collections/...
# 3  https://scholarship.rice.edu/rest/collections/...

# %% [markdown]
# Step 3: Find all item records that live in any collection. Tag each item with the collection it came from.

# %%
combine = []
parentcollections = []
names = []

for idx, row in allcollections.iterrows():
    response = requests.get(row['link'] + "?limit=1000")
    items = json.loads(response.text)

    for item in items:
        itemno = item['handle'].split('/')[1]
        combine.append(itemno)
        names.append(item['name'])
        parentcollections.append(row['handle'])

allitems = pd.DataFrame({'itemhandle': combine, 'handle': parentcollections, 'name': names})
allitems['link'] = 'https://scholarship.rice.edu/handle/1911/' + allitems['itemhandle'] + '/statistics'
allitems
# Out:
#      itemhandle handle                                               name  \
# 0          9305   9305                             Cairo (Masr El-Kahira)
# 1          9417   9305  Map of Cook's Steamer and Dahabeah Service of ...
# 2          9299   9305                            The Delta (Lower Egypt)
# 1237  https://scholarship.rice.edu/handle/1911/10044...
# 1238  https://scholarship.rice.edu/handle/1911/10016...
# 1239  https://scholarship.rice.edu/handle/1911/9936/...
#
# [1240 rows x 4 columns]

# %% [markdown]
# Step 4: Query each item record to find all associated files, and for each file, extract how many views it has.

# %%
allrecords = pd.DataFrame({"itemhandle": [], "filename":[], "views": []})

for idx, row in allitems.iterrows():
    url = row['link']
    r = requests.get(url)
    page = r.text
    soup = bs(page,'html.parser')
   
    res = soup.find_all('table', {'id':"aspect_statistics_StatisticsTransformer_table_list-table"})
    headings = soup.find_all('h3', class_='ds-table-head')
   
    labels = []
    data = []
    handles = []
    
    index = 0
   
    for heading in headings:
        if heading.string == 'File Visits':
            record = res[index]
            labels.extend(list(map(lambda rec: rec.string, record.find_all('td', class_='labelcell'))))
            data.extend(list(map(lambda rec: rec.string, record.find_all('td', class_='datacell'))))
            handles.extend(list(map(lambda rec: row['handle'], record.find_all('td', class_='datacell'))))
        index += 1
       
    itemfiles = pd.DataFrame({'itemhandle': handles, 'filename': labels, 'views': data})
    allrecords = pd.concat([allrecords, itemfiles], ignore_index=True)
    
allrecords
# Out:
#      itemhandle                            filename views
# 0          9305                              197540  1671
# 1          9305           BaeEg2a_228be.jpg(legacy)   733
# 2          9305                   BaeEg2a_228be.jpg   103
# 3          9305                   BaeEg2a_228be.jp2    42
# 4          9305                              197585  2088
# 5          9305           BudNi1895_f05.jpg(legacy)   344
# 6          9305                   BudNi1895_f05.jpg   131
# 7          9305                   BudNi1895_f05.jp2    33
# 8          9305                              197589  1961
# 9          9305            BaeEg2a_007b.jpg(legacy)  1730
# 10         9305                    BaeEg2a_007b.jpg   287
# 11         9305                    BaeEg2a_007b.jp2    40
# 12         9305                              197592  1521
# 13         9305              BaeEg4016a.jpg(legacy)   222
# 14         9305                      BaeEg4016a.jp2    28
# 15         9305                      BaeEg4016a.jpg     9
# 16         9305                     BaeEg4168bc.jp2    13
# 17         9305                     BaeEg6180bc.jp2    65
# 18         9305                       PooSt_328.jp2    19
# 19         9305                              197490  1688
# 20         9305            BaeEg2a_222a.jpg(legacy)  1196
# 21         9305                    BaeEg2a_222a.jpg   127
# 22         9305                    BaeEg2a_222a.jp2    25
# 23         9305                              197491  1004
# 24         9305              BaeEg6030b.jpg(legacy)   267
# 25         9305                      BaeEg6030b.jp2    36
# 26         9305                      BaeEg6030b.jpg    33
# 27         9305                              197494  1216
# 28         9305                    BreEgMaps_15.jpg   219
# 29         9305            BreEgMaps_15.jpg(legacy)   204
# ...         ...                                 ...   ...
# 5222      10329                              215544  2111
# 5223      10329         EgyRe_027_illus.jpg(legacy)   688
# 5224      10329                 EgyRe_027_illus.jpg    40
# 5225      10329                              215545   443
# 5226      10329        SlaOr_252a_illus.jpg(legacy)   245
# 5227      10329                SlaOr_252a_illus.jpg    42
# 5228      10329                              215548   541
# 5229      10329   LanMa1836v1_176_illus.jpg(legacy)    81
# 5230      10329           LanMa1836v1_176_illus.jpg     4
# 5231      10329        MarCa_042a_illus.jpg(legacy)   760
# 5232      10329                              215549   594
# 5233      10329                MarCa_042a_illus.jpg    42
# 5234      10329        SlaOr_064a_illus.jpg(legacy)  1525
# 5235      10329                              215551   554
# 5236      10329                SlaOr_064a_illus.jpg   230
# 5237      10329                              215555   398
# 5238      10329        MarCa_204a_illus.jpg(legacy)    98
# 5239      10329                MarCa_204a_illus.jpg    25
# 5240      10329                              215556  1055
# 5241      10329         PooSt_029_illus.jpg(legacy)    96
# 5242      10329                 PooSt_029_illus.jpg    22
# 5243      10329                              215558   565
# 5244      10329  LanMa1836v1_017b_illus.jpg(legacy)    83
# 5245      10329          LanMa1836v1_017b_illus.jpg    11
# 5246      10329                              215561   479
# 5247      10329         HagPi065a_illus.jpg(legacy)   121
# 5248      10329                 HagPi065a_illus.jpg    27
# 5249      10329                              215562   721
# 5250      10329       BaeEg2133_c_illus.jpg(legacy)   106
# 5251      10329               BaeEg2133_c_illus.jpg    36
#
# [5252 rows x 3 columns]

# %% [markdown]
# Step 5: Merge the tables we have created to produce a final dataframe with only File Name, Views, and Collection Name as columns.

# %%
final = allrecords.merge(allitems.merge(allcollections, on='handle'),on='itemhandle')
final = final[['filename', 'views', 'collectionname']]
final['views'] = final.views.astype(int)
final
# Out:
#                                 filename  views  \
# 0                                 197540   1671
# 1              BaeEg2a_228be.jpg(legacy)    733
# 2                      BaeEg2a_228be.jpg    103
# 3                      BaeEg2a_228be.jp2     42
# 4                                 197585   2088
# 5              BudNi1895_f05.jpg(legacy)    344
# 6                      BudNi1895_f05.jpg    131
# 7                      BudNi1895_f05.jp2     33
# 8                                 197589   1961
# 9               BaeEg2a_007b.jpg(legacy)   1730
# 10                      BaeEg2a_007b.jpg    287
# 11                      BaeEg2a_007b.jp2     40
# 12                                197592   1521
# 13                BaeEg4016a.jpg(legacy)    222
# 14                        BaeEg4016a.jp2     28
# 15                        BaeEg4016a.jpg      9
# 16                       BaeEg4168bc.jp2     13
# 17                       BaeEg6180bc.jp2     65
# 18                         PooSt_328.jp2     19
# 19                                197490   1688
# 20              BaeEg2a_222a.jpg(legacy)   1196
# 21                      BaeEg2a_222a.jpg    127
# 22                      BaeEg2a_222a.jp2     25
# 23                                197491   1004
# 24                BaeEg6030b.jpg(legacy)    267
# 25                        BaeEg6030b.jp2     36
# 26                        BaeEg6030b.jpg     33
# 27                                197494   1216
# 28                      BreEgMaps_15.jpg    219
# 29              BreEgMaps_15.jpg(legacy)    204
# ...                                  ...    ...
# 5222                              215544   2111
# 5223         EgyRe_027_illus.jpg(legacy)    688
# 5224                 EgyRe_027_illus.jpg     40
# 5225                              215545    443
# 5226        SlaOr_252a_illus.jpg(legacy)    245
# 5227                SlaOr_252a_illus.jpg     42
# 5228                              215548    541
# 5229   LanMa1836v1_176_illus.jpg(legacy)     81
# 5230           LanMa1836v1_176_illus.jpg      4
# 5231        MarCa_042a_illus.jpg(legacy)    760
# 5232                              215549    594
# 5233                MarCa_042a_illus.jpg     42
# 5234        SlaOr_064a_illus.jpg(legacy)   1525
# 5235                              215551    554
# 5236                SlaOr_064a_illus.jpg    230
# 5237                              215555    398
# 5238        MarCa_204a_illus.jpg(legacy)     98
# 5239                MarCa_204a_illus.jpg     25
# 5240                              215556   1055
# 5241         PooSt_029_illus.jpg(legacy)     96
# 5242                 PooSt_029_illus.jpg     22
# 5243                              215558    565
# 5244  LanMa1836v1_017b_illus.jpg(legacy)     83
# 5245          LanMa1836v1_017b_illus.jpg     11
# 5246                              215561    479
# 5247         HagPi065a_illus.jpg(legacy)    121
# 5248                 HagPi065a_illus.jpg     27
# 5249                              215562    721
# 5250       BaeEg2133_c_illus.jpg(legacy)    106
# 5251               BaeEg2133_c_illus.jpg     36
#
#                        collectionname
# 0     TIMEA Historical Maps and Plans
# 1     TIMEA Historical Maps and Plans
# 2     TIMEA Historical Maps and Plans
# 3     TIMEA Historical Maps and Plans
# 4     TIMEA Historical Maps and Plans
# 5     TIMEA Historical Maps and Plans
# 6     TIMEA Historical Maps and Plans
# 7     TIMEA Historical Maps and Plans
# 8     TIMEA Historical Maps and Plans
# 9     TIMEA Historical Maps and Plans
# 10    TIMEA Historical Maps and Plans
# 11    TIMEA Historical Maps and Plans
# 12    TIMEA Historical Maps and Plans
# 13    TIMEA Historical Maps and Plans
# 14    TIMEA Historical Maps and Plans
# 15    TIMEA Historical Maps and Plans
# 16    TIMEA Historical Maps and Plans
# 17    TIMEA Historical Maps and Plans
# 18    TIMEA Historical Maps and Plans
# 19    TIMEA Historical Maps and Plans
# 20    TIMEA Historical Maps and Plans
# 21    TIMEA Historical Maps and Plans
# 22    TIMEA Historical Maps and Plans
# 23    TIMEA Historical Maps and Plans
# 24    TIMEA Historical Maps and Plans
# 25    TIMEA Historical Maps and Plans
# 26    TIMEA Historical Maps and Plans
# 27    TIMEA Historical Maps and Plans
# 28    TIMEA Historical Maps and Plans
# 29    TIMEA Historical Maps and Plans
# ...                               ...
# 5222          TIMEA Visual Materials
# 5223          TIMEA Visual Materials
# 5224          TIMEA Visual Materials
# 5225          TIMEA Visual Materials
# 5226          TIMEA Visual Materials
# 5227          TIMEA Visual Materials
# 5228          TIMEA Visual Materials
# 5229          TIMEA Visual Materials
# 5230          TIMEA Visual Materials
# 5231          TIMEA Visual Materials
# 5232          TIMEA Visual Materials
# 5233          TIMEA Visual Materials
# 5234          TIMEA Visual Materials
# 5235          TIMEA Visual Materials
# 5236          TIMEA Visual Materials
# 5237          TIMEA Visual Materials
# 5238          TIMEA Visual Materials
# 5239          TIMEA Visual Materials
# 5240          TIMEA Visual Materials
# 5241          TIMEA Visual Materials
# 5242          TIMEA Visual Materials
# 5243          TIMEA Visual Materials
# 5244          TIMEA Visual Materials
# 5245          TIMEA Visual Materials
# 5246          TIMEA Visual Materials
# 5247          TIMEA Visual Materials
# 5248          TIMEA Visual Materials
# 5249          TIMEA Visual Materials
# 5250          TIMEA Visual Materials
# 5251          TIMEA Visual Materials
#
# [5252 rows x 3 columns]

# %% [markdown]
# Step 6: Group by collection name and aggregate the number of views for all files in each community.

# %%
final.groupby('collectionname').count()
# Out:
#                                  filename  views
# collectionname
# TIMEA Historical Maps and Plans       595    595
# TIMEA Research                         28     28
# TIMEA Texts                           699    699
# TIMEA Visual Materials               3930   3930

# %%
final.groupby('collectionname').views.sum()
# Out:
# collectionname
# TIMEA Historical Maps and Plans     303800
# TIMEA Research                        8851
# TIMEA Texts                        1296840
# TIMEA Visual Materials             1019152
# Name: views, dtype: int64
