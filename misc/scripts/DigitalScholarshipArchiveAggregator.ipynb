# %% [markdown]
# ### Aggregation of Digital Scholarship Archive File Data
#
# The following code uses the REST API provided by Rice's Digital Scholarship Archive (https://scholarship.rice.edu/rest) to aggregate statistics for file views present in the archive by community and collection.

# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
def get_community(jsonroot, name):
    """
    Recursively find a community in dictionary jsonroot 
    with the given name.
    Returns None if no match is found.
    """
    community = None
    for subcommunity in jsonroot['community']:
        if subcommunity['name'] == name:
            return subcommunity
        subsearch = get_community(subcommunity, name)
        if subsearch:
            return subsearch
        
    return None

# %%
def get_all_collections(jsonroot, prefix=""):
    """
    Recursively find all collections in dictionary jsonroot.
    Returns a dataframe with columns id, name, and handle.
    """
    ids = []
    names = []
    handles = []

    if not prefix[-3:] == " > ":
        prefix = str(jsonroot['name']) + " > "
    
    for collection in jsonroot['collection']:
        ids.append(collection['id'])
        names.append(prefix + str(collection['name']))
        handles.append(collection['handle'])
        
    collections = pd.DataFrame({'id': ids, 'name': names, 'handle': handles})
    
    for subcommunity in jsonroot['community']:
        subframe = get_all_collections(subcommunity, prefix=(prefix + str(subcommunity['name']) + " > "))
        collections = pd.concat([collections, subframe], ignore_index=True)
    
    return collections

# %% [markdown]
# Step 1: Find the community of interest.

# %%
# the hierarchy page contains the entire tree-like structure of the Digital Scholarship Archive,
#   where a community is an interior node and a collection is a leaf with associated file data.
hierarchyurl = 'https://scholarship.rice.edu/rest/hierarchy'

response = requests.get(hierarchyurl)
data = json.loads(response.text)
communitydata = get_community(data, 'Chao Center for Asian Studies')

# %% [markdown]
# Step 2: Extract all collections.

# %%
allcollections = get_all_collections(communitydata)
list(allcollections.name)[:5]
# Out:
# ['Chao Center for Asian Studies > Bobby Joe Moon family genealogy collection (MS 581)',
#  "Chao Center for Asian Studies > Braes Republican Women's Club records, 1980-2009 (MS 601)",
#  'Chao Center for Asian Studies > Chinese American Citizens Alliance records (Houston Chapter) (MS 606)',
#  'Chao Center for Asian Studies > Chuan-Hua Gershom Lowe, National Party, Chinese diplomat papers, 1923-1996 (MS 588)',
#  'Chao Center for Asian Studies > Dr. Ed C. M. Chen collection of oral history interviews with Asian American Houstonians, 1980s (MS 646)']

# %%
allcollections = get_all_collections(communitydata)
allcollections['url'] = 'https://scholarship.rice.edu/rest/collections/' + allcollections['id'] + '/items'

handles = []
collectionnames = []
collectionurls = []

for idx, row in allcollections.iterrows():
    url = row['url']
    
    response = requests.get(url)
    jresponse = json.loads(response.text)

    # annoyingly, there are collections with no items.
    #  this test will throw out such collections.
    if len(jresponse) == 0:
        continue

    data = jresponse[0]
    handles.append(data['handle'].split("/")[1])
    collectionnames.append(row['name'])
    collectionurls.append(url)
    
allcollections = pd.DataFrame({'handle': handles, 'collectionname': collectionnames, 'link': collectionurls})
allcollections
# Out:
#     handle                                     collectionname  \
# 0    75178  Chao Center for Asian Studies > Bobby Joe Moon...
# 1    77623  Chao Center for Asian Studies > Braes Republic...
# 2    75797  Chao Center for Asian Studies > Chinese Americ...
# 3    77631  Chao Center for Asian Studies > Chuan-Hua Gers...
# 4    64031  Chao Center for Asian Studies > Dr. Ed C. M. C...
# 5   101509  Chao Center for Asian Studies > Edward Chen fa...
# 6    75180  Chao Center for Asian Studies > Gene and Hedy ...
# 7    68486  Chao Center for Asian Studies > Vietnamese Ame...
# 8   100395  Chao Center for Asian Studies > Ephemera Archi...
# 9   100667  Chao Center for Asian Studies > Ephemera Archi...
# 10   99893  Chao Center for Asian Studies > Ephemera Archi...
# 11   99832  Chao Center for Asian Studies > Ephemera Archi...
# 12   57879  Chao Center for Asian Studies > Ephemera Archi...
# 13   41175  Chao Center for Asian Studies > Ephemera Archi...
# 14   41543  Chao Center for Asian Studies > Ephemera Archi...
# 15   40034  Chao Center for Asian Studies > Ephemera Archi...
# 16   42080  Chao Center for Asian Studies > Ephemera Archi...
# 17   43568  Chao Center for Asian Studies > Ephemera Archi...
# 18   99244  Chao Center for Asian Studies > Houston Asian ...
#
#                                                  link
# 0   https://scholarship.rice.edu/rest/collections/...
# 1   https://scholarship.rice.edu/rest/collections/...
# 2   https://scholarship.rice.edu/rest/collections/...
# 3   https://scholarship.rice.edu/rest/collections/...
# 4   https://scholarship.rice.edu/rest/collections/...
# 5   https://scholarship.rice.edu/rest/collections/...
# 6   https://scholarship.rice.edu/rest/collections/...
# 7   https://scholarship.rice.edu/rest/collections/...
# 8   https://scholarship.rice.edu/rest/collections/...
# 9   https://scholarship.rice.edu/rest/collections/...
# 10  https://scholarship.rice.edu/rest/collections/...
# 11  https://scholarship.rice.edu/rest/collections/...
# 12  https://scholarship.rice.edu/rest/collections/...
# 13  https://scholarship.rice.edu/rest/collections/...
# 14  https://scholarship.rice.edu/rest/collections/...
# 15  https://scholarship.rice.edu/rest/collections/...
# 16  https://scholarship.rice.edu/rest/collections/...
# 17  https://scholarship.rice.edu/rest/collections/...
# 18  https://scholarship.rice.edu/rest/collections/...

# %% [markdown]
# Step 3: Find all item records that live in any collection. Tag each item with the collection it came from.

# %%
combine = []
parentcollections = []
names = []

pagesize = 1000

for idx, row in allcollections.iterrows():
    # handle pagination
    offset = 0
    stop = False
    
    while not stop:
        # get a page of data
        response = requests.get(row['link'], params={'limit': pagesize, 'offset': offset})
        items = json.loads(response.text)

        # extract item handle, item name, and tag with parent collection.
        for item in items:
            itemno = item['handle'].split('/')[1]
            combine.append(itemno)
            names.append(item['name'])
            parentcollections.append(row['handle'])
            
        # if we have fewer than pagesize records, then we are done.
        #  otherwise, get the next page.
        if len(items) < pagesize:
            stop = True
        else:
            offset += pagesize

allitems = pd.DataFrame({'itemhandle': combine, 'handle': parentcollections, 'name': names})
allitems['link'] = 'https://scholarship.rice.edu/handle/1911/' + allitems['itemhandle'] + '/statistics'
allitems
# Out:
#      itemhandle handle                                               name  \
# 0         75178  75178  Moon family at time of arrival in United State...
# 1         75176  75178            Joe Bros. store, Cleveland, Mississippi
# 2         75177  75178  Newsclipping featuring image of parents of Bob...
# 3         77623  77623  Braes Republican Women's Club swearing in cere...
# 4         77624  77623  Greater Houston Council of Federated Republica...
# 5         77622  77623  Braes Republican Women's Club bylaws and philo...
# 6         77625  77623  Braes Republican Women scrapbook pages featuri...
# 7         75797  75797    Miss Chinatown Houston Pageant Day proclamation
# 8         75798  75797  Chinese American Citizens Alliance Houston Lod...
# 9         75799  75797  Houston Lodge Chinese American Citizens Allian...
# 10        75801  75797  Houston Lodge Chinese American Citizens Allian...
# 11        75802  75797  36th Annual Miss Chinatown Houston Scholarship...
    r = requests.get(url)
    page = r.text
    soup = bs(page,'html.parser')
   
    res = soup.find_all('table', {'id':"aspect_statistics_StatisticsTransformer_table_list-table"})
    headings = soup.find_all('h3', class_='ds-table-head')
   
    labels = []
    data = []
    handles = []
    
    index = 0
   
    for heading in headings:
        if heading.string == 'File Visits':
            record = res[index]
            labels.extend(list(map(lambda rec: rec.string, record.find_all('td', class_='labelcell'))))
            data.extend(list(map(lambda rec: rec.string, record.find_all('td', class_='datacell'))))
            handles.extend(list(map(lambda rec: row['handle'], record.find_all('td', class_='datacell'))))
        index += 1
       
    itemfiles = pd.DataFrame({'itemhandle': handles, 'filename': labels, 'views': data})
    allrecords = pd.concat([allrecords, itemfiles], ignore_index=True)
    
allrecords
# Out:
#       itemhandle                                filename views
# 0          75178                    wrc03901.jpg(legacy)    72
# 1          75178                    wrc03901.jp2(legacy)    24
# 2          75178                            wrc03901.jp2    18
# 3          75178                            wrc03901.jpg     2
# 4          75178                    wrc03899.jpg(legacy)    65
# 5          75178                            wrc03899.jpg    35
# 6          75178                            wrc03899.jp2    23
# 7          75178                    wrc03899.jp2(legacy)    14
# 8          75178                    wrc03900.pdf(legacy)   256
# 9          75178                            wrc03900.pdf    58
# 10         77623                            wrc05212.jpg    33
# 11         77623                    wrc05212.jpg(legacy)    21
# 12         77623                    wrc05213.pdf(legacy)   360
# 13         77623                            wrc05213.pdf   239
# 14         77623                            wrc05211.pdf   135
# 15         77623                    wrc05211.pdf(legacy)    61
# 16         77623                        wrc05214_002.jp2    24
# 17         77623                wrc05214_001.jpg(legacy)    20
# 18         77623                wrc05214_002.jpg(legacy)    14
# 19         77623                wrc05214_001.jp2(legacy)    11
# 20         77623                wrc05214_002.jp2(legacy)    10
# 21         77623                        wrc05214_001.jp2     1
# 22         77623                        wrc05214_002.jpg     1
# 23         75797                    wrc04242.pdf(legacy)    56
# 24         75797                            wrc04242.pdf    17
# 25         75797                    wrc04243.pdf(legacy)    42
# 26         75797                            wrc04243.pdf    38
# 27         75797                    wrc04244.pdf(legacy)    72
# 28         75797                            wrc04244.pdf    35
# 29         75797                    wrc04253.pdf(legacy)    84
# ...          ...                                     ...   ...
# 22898      99244                 wrc09113_transcript.pdf     9
# 22899      99244                            wrc09113.mp4     6
# 22900      99244             wrc09143_transcript-rev.pdf    43
# 22901      99244    e12b129c-d5b9-4429-8644-fa46151fdf32    10
# 22902      99244    4baa62ac-5631-472d-8ce2-061bc63d7183     6
# 22903      99244                 wrc09166_transcript.pdf    52
# 22904      99244                wrc09166_interviewee.jpg    16
# 22905      99244                     wrc09166_access.mp4     3
# 22906      99244            wrc09164_transcript-rev2.pdf    24
# 22907      99244    0e0064c2-9a47-47f9-a9b1-3bb1de5b6877    20
# 22908      99244  wrc09164_with_daughter_Linda Epner.jpg    15
# 22909      99244                wrc09164_interviewee.jpg    15
# 22910      99244    028d5eb4-feea-4504-9ae5-c668b5948cc6    12
# 22911      99244    d0df81d3-808c-4497-bd9e-49d91c3416c0    10
# 22912      99244                     wrc09164_access.mp4     3
# 22913      99244                 wrc09165_transcript.pdf    49
# 22914      99244                wrc09165_interviewee.jpg    21
# 22915      99244                     wrc09165_access.mp4     3
# 22916      99244                 wrc01967_transcript.pdf    49
# 22917      99244                wrc01967_interviewee.jpg    10
# 22918      99244                     wrc01967_access.mp4     3
# 22919      99244                 wrc09168_transcript.pdf    41
# 22920      99244                            wrc09168.mp3     2
# 22921      99244                 wrc09174_transcript.pdf    48
# 22922      99244             wrc09175_transcript-rev.pdf    41
# 22923      99244                wrc09175_interviewee.jpg    11
# 22924      99244    792e6eed-ce09-46a6-9c56-bd7b5fddb401     4
# 22925      99244                 wrc09176_transcript.pdf    40
# 22926      99244                 wrc09177_transcript.pdf    39
# 22927      99244                wrc09177_interviewee.JPG    17
#
# [22928 rows x 3 columns]

# %% [markdown]
# Step 5: Merge the tables we have created to produce a final dataframe with only File Name, Views, and Collection Name as columns.

# %%
final = allrecords.merge(allitems.merge(allcollections, on='handle'),on='itemhandle')
final = final[['filename', 'views', 'collectionname']]
final['views'] = final.views.astype(int)
final
# Out:
#                                      filename  views  \
# 0                        wrc03901.jpg(legacy)     72
# 1                        wrc03901.jp2(legacy)     24
# 2                                wrc03901.jp2     18
# 3                                wrc03901.jpg      2
# 4                        wrc03899.jpg(legacy)     65
# 5                                wrc03899.jpg     35
# 6                                wrc03899.jp2     23
# 7                        wrc03899.jp2(legacy)     14
# 8                        wrc03900.pdf(legacy)    256
# 9                                wrc03900.pdf     58
# 10                               wrc05212.jpg     33
# 11                       wrc05212.jpg(legacy)     21
# 12                       wrc05213.pdf(legacy)    360
# 13                               wrc05213.pdf    239
# 14                               wrc05211.pdf    135
# 15                       wrc05211.pdf(legacy)     61
# 16                           wrc05214_002.jp2     24
# 17                   wrc05214_001.jpg(legacy)     20
# 18                   wrc05214_002.jpg(legacy)     14
# 19                   wrc05214_001.jp2(legacy)     11
# 20                   wrc05214_002.jp2(legacy)     10
# 21                           wrc05214_001.jp2      1
# 22                           wrc05214_002.jpg      1
# 23                       wrc04242.pdf(legacy)     56
# 24                               wrc04242.pdf     17
# 25                       wrc04243.pdf(legacy)     42
# 26                               wrc04243.pdf     38
# 27                       wrc04244.pdf(legacy)     72
# 28                               wrc04244.pdf     35
# 29                       wrc04253.pdf(legacy)     84
# ...                                       ...    ...
# 22898                 wrc09113_transcript.pdf      9
# 22899                            wrc09113.mp4      6
# 22900             wrc09143_transcript-rev.pdf     43
# 22901    e12b129c-d5b9-4429-8644-fa46151fdf32     10
# 22902    4baa62ac-5631-472d-8ce2-061bc63d7183      6
# 22903                 wrc09166_transcript.pdf     52
# 22904                wrc09166_interviewee.jpg     16
# 22905                     wrc09166_access.mp4      3
# 22906            wrc09164_transcript-rev2.pdf     24
# 22907    0e0064c2-9a47-47f9-a9b1-3bb1de5b6877     20
# 22908  wrc09164_with_daughter_Linda Epner.jpg     15
# 22909                wrc09164_interviewee.jpg     15
# 22910    028d5eb4-feea-4504-9ae5-c668b5948cc6     12
# 22911    d0df81d3-808c-4497-bd9e-49d91c3416c0     10
# 22912                     wrc09164_access.mp4      3
# 22913                 wrc09165_transcript.pdf     49
# 22914                wrc09165_interviewee.jpg     21
# 22915                     wrc09165_access.mp4      3
# 22916                 wrc01967_transcript.pdf     49
# 22917                wrc01967_interviewee.jpg     10
# 22918                     wrc01967_access.mp4      3
# 22919                 wrc09168_transcript.pdf     41
# 22921  Chao Center for Asian Studies > Houston Asian ...
# 22922  Chao Center for Asian Studies > Houston Asian ...
# 22923  Chao Center for Asian Studies > Houston Asian ...
# 22924  Chao Center for Asian Studies > Houston Asian ...
# 22925  Chao Center for Asian Studies > Houston Asian ...
# 22926  Chao Center for Asian Studies > Houston Asian ...
# 22927  Chao Center for Asian Studies > Houston Asian ...
#
# [22928 rows x 3 columns]

# %% [markdown]
# Step 6: Group by collection name and aggregate the number of views for all files in each community.

# %%
final.groupby('collectionname').filename.count()
# Out:
# collectionname
# Chao Center for Asian Studies > Bobby Joe Moon family genealogy collection (MS 581)                                                                10
# Chao Center for Asian Studies > Braes Republican Women's Club records, 1980-2009 (MS 601)                                                          13
# Chao Center for Asian Studies > Chinese American Citizens Alliance records (Houston Chapter) (MS 606)                                              50
# Chao Center for Asian Studies > Chuan-Hua Gershom Lowe, National Party, Chinese diplomat papers, 1923-1996 (MS 588)                                 8
# Chao Center for Asian Studies > Dr. Ed C. M. Chen collection of oral history interviews with Asian American Houstonians, 1980s (MS 646)           105
# Chao Center for Asian Studies > Edward Chen family collection, 1920-2010 (MS 561)                                                                   6
# Chao Center for Asian Studies > Ephemera Archive > Chinese Commercial Advertisement Archive > Hankow Times, Hankou, China [汉口中西报，中国汉口] > 1932     541
# Chao Center for Asian Studies > Ephemera Archive > Chinese Commercial Advertisement Archive > Hankow Times, Hankou, China [汉口中西报，中国汉口] > 1933    1657
# Chao Center for Asian Studies > Ephemera Archive > Chinese Commercial Advertisement Archive > Hankow Times, Hankou, China [汉口中西报，中国汉口] > 1937     502
# Chao Center for Asian Studies > Ephemera Archive > Chinese Commercial Advertisement Archive > Yuet Wa Po, Guangzhou, China [越华报，中国广州] > 1929      112
# Chao Center for Asian Studies > Ephemera Archive > Subway Advertisement Archive > Beijing                                                        4730
# Chao Center for Asian Studies > Ephemera Archive > Subway Advertisement Archive > Hongkong                                                       1755
# Chao Center for Asian Studies > Ephemera Archive > Subway Advertisement Archive > Kaoshiung                                                       171
# Chao Center for Asian Studies > Ephemera Archive > Subway Advertisement Archive > Shanghai                                                       4958
# Chao Center for Asian Studies > Ephemera Archive > Subway Advertisement Archive > Singapore                                                      1965
# Chao Center for Asian Studies > Ephemera Archive > Subway Advertisement Archive > Taipei                                                         4090
# Chao Center for Asian Studies > Gene and Hedy Lee Chinese newspapers and photographs collection, 1962-2010 (MS 556)                                 4
# Chao Center for Asian Studies > Houston Asian American Archives (HAAA) oral histories > Houston Asian American Archives oral histories           1465
# Chao Center for Asian Studies > Vietnamese American Heritage Foundation (VAHF) interviews                                                         786
# Name: filename, dtype: int64

# %%
final.groupby('collectionname').views.sum()
# Out:
# collectionname
# Chao Center for Asian Studies > Bobby Joe Moon family genealogy collection (MS 581)                                                                 567
# Chao Center for Asian Studies > Braes Republican Women's Club records, 1980-2009 (MS 601)                                                           930
# Chao Center for Asian Studies > Chinese American Citizens Alliance records (Houston Chapter) (MS 606)                                              2361
# Chao Center for Asian Studies > Chuan-Hua Gershom Lowe, National Party, Chinese diplomat papers, 1923-1996 (MS 588)                                 322
# Chao Center for Asian Studies > Dr. Ed C. M. Chen collection of oral history interviews with Asian American Houstonians, 1980s (MS 646)            6086
# Chao Center for Asian Studies > Edward Chen family collection, 1920-2010 (MS 561)                                                                  4908
# Chao Center for Asian Studies > Ephemera Archive > Chinese Commercial Advertisement Archive > Hankow Times, Hankou, China [汉口中西报，中国汉口] > 1932     10339
# Chao Center for Asian Studies > Ephemera Archive > Chinese Commercial Advertisement Archive > Hankow Times, Hankou, China [汉口中西报，中国汉口] > 1933     26872
# Chao Center for Asian Studies > Ephemera Archive > Chinese Commercial Advertisement Archive > Hankow Times, Hankou, China [汉口中西报，中国汉口] > 1937     14023
# Chao Center for Asian Studies > Ephemera Archive > Chinese Commercial Advertisement Archive > Yuet Wa Po, Guangzhou, China [越华报，中国广州] > 1929       2054
# Chao Center for Asian Studies > Ephemera Archive > Subway Advertisement Archive > Beijing                                                        249243
# Chao Center for Asian Studies > Ephemera Archive > Subway Advertisement Archive > Hongkong                                                       113457
# Chao Center for Asian Studies > Ephemera Archive > Subway Advertisement Archive > Kaoshiung                                                        7804
# Chao Center for Asian Studies > Ephemera Archive > Subway Advertisement Archive > Shanghai                                                       264459
# Chao Center for Asian Studies > Ephemera Archive > Subway Advertisement Archive > Singapore                                                      162126
# Chao Center for Asian Studies > Ephemera Archive > Subway Advertisement Archive > Taipei                                                         191632
# Chao Center for Asian Studies > Gene and Hedy Lee Chinese newspapers and photographs collection, 1962-2010 (MS 556)                                 107
# Chao Center for Asian Studies > Houston Asian American Archives (HAAA) oral histories > Houston Asian American Archives oral histories           121346
# Chao Center for Asian Studies > Vietnamese American Heritage Foundation (VAHF) interviews                                                        117220
# Name: views, dtype: int64
