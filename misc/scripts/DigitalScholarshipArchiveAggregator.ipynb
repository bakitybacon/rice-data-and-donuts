# %% [markdown]
# ### Aggregation of Digital Scholarship Archive File Data
#
# The following code uses the REST API provided by Rice's Digital Scholarship Archive (https://scholarship.rice.edu/rest) to aggregate statistics for file views present in the archive by community and collection.

# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
def get_community(jsonroot, name):
    """
    Recursively find a community in dictionary jsonroot 
    with the given name.
    Returns None if no match is found.
    """
    community = None
    for subcommunity in jsonroot['community']:
        if subcommunity['name'] == name:
            return subcommunity
        subsearch = get_community(subcommunity, name)
        if subsearch:
            return subsearch
        
    return None

# %%
def get_all_collections(jsonroot):
    """
    Recursively find all collections in dictionary jsonroot.
    Returns a dataframe with columns id, name, and handle.
    """
    ids = []
    names = []
    handles = []
    
    for collection in jsonroot['collection']:
        ids.append(collection['id'])
        names.append(collection['name'])
        handles.append(collection['handle'])
        
    collections = pd.DataFrame({'id': ids, 'name': names, 'handle': handles})
    
    for subcommunity in jsonroot['community']:
        subframe = get_all_collections(subcommunity)
        collections = pd.concat([collections, subframe], ignore_index=True)
    
    return collections

# %% [markdown]
# Step 1: Find the community of interest.

# %%
# the hierarchy page contains the entire tree-like structure of the Digital Scholarship Archive,
#   where a community is an interior node and a collection is a leaf with associated file data.
hierarchyurl = 'https://scholarship.rice.edu/rest/hierarchy'

response = requests.get(hierarchyurl)
data = json.loads(response.text)
communitydata = get_community(data, 'Subway Advertisement Archive')

# %% [markdown]
# Step 2: Extract all collections.

# %%
allcollections = get_all_collections(communitydata)
allcollections['url'] = 'https://scholarship.rice.edu/rest/collections/' + allcollections['id'] + '/items'

handles = []
collectionnames = []
collectionurls = []

for idx, row in allcollections.iterrows():
    url = row['url']
    
    response = requests.get(url)
    jresponse = json.loads(response.text)

    # annoyingly, there are collections with no items.
    #  this test will throw out such collections.
    if len(jresponse) == 0:
        continue

    data = jresponse[0]
    handles.append(data['handle'].split("/")[1])
    collectionnames.append(row['name'])
    collectionurls.append(url)
    
allcollections = pd.DataFrame({'handle': handles, 'collectionname': collectionnames, 'link': collectionurls})
allcollections
# Out:
#   handle collectionname                                               link
# 0  57879        Beijing  https://scholarship.rice.edu/rest/collections/...
# 1  41175       Hongkong  https://scholarship.rice.edu/rest/collections/...
# 2  41543      Kaoshiung  https://scholarship.rice.edu/rest/collections/...
# 3  40034       Shanghai  https://scholarship.rice.edu/rest/collections/...
# 4  42080      Singapore  https://scholarship.rice.edu/rest/collections/...
# 5  43568         Taipei  https://scholarship.rice.edu/rest/collections/...

# %% [markdown]
# Step 3: Find all item records that live in any collection. Tag each item with the collection it came from.

# %%
combine = []
parentcollections = []
names = []

pagesize = 1000

for idx, row in allcollections.iterrows():
    # handle pagination
    offset = 0
    stop = False
    
    while not stop:
        # get a page of data
        response = requests.get(row['link'], params={'limit': pagesize, 'offset': offset})
        items = json.loads(response.text)

        # extract item handle, item name, and tag with parent collection.
        for item in items:
            itemno = item['handle'].split('/')[1]
            combine.append(itemno)
            names.append(item['name'])
            parentcollections.append(row['handle'])
            
        # if we have fewer than pagesize records, then we are done.
        #  otherwise, get the next page.
        if len(items) < pagesize:
            stop = True
        else:
            offset += pagesize

allitems = pd.DataFrame({'itemhandle': combine, 'handle': parentcollections, 'name': names})
allitems['link'] = 'https://scholarship.rice.edu/handle/1911/' + allitems['itemhandle'] + '/statistics'
allitems
# Out:
#      itemhandle handle                                               name  \
# 0         57879  57879  China Putian Cell Phone, China Putian. www.cap...
# 1         57904  57879                Motorola Cell Phone, Motorola C300.
# 2         57914  57879       China Merchants Securities Co., Ltd. (CCSC),
# 3         57934  57879                            Olympus Camera, Olympus
# 4         57935  57879                        Colgate toothbrush, Colgate
# 5         57943  57879               Cadbury Chocolate, Cadbury Chocolate
# 6         57946  57879                   Beijing Metro Service Standards,
# 7         57947  57879        Sparkle Fashion, Sparkle. Everyday fashion.
# 8         57949  57879                                   China Orchestra,
# 9         57954  57879  South Australia Trip, Perth. Western Australia...
# 10        57956  57879                                        Teda Shirt,
# 11        57957  57879                                     Cadina, Cadina
# 12        57959  57879                             21cn.com, www.21cn.com
# 13        57961  57879                                        Top Resort,
# 14        57858  57879                              Australia Coast Trip,
# 15        57859  57879                                China Post Service,
# 16        57863  57879                                       Nokia, Nokia
# 17        57865  57879                                   Olympic Athlete,
# 18        57868  57879                                     Dupont, Dupont
# 19        57871  57879  Star Cruises Trip, Star Cruises. CTI. www.star...
# 20        57872  57879  Beijing International Tourism Culture Festival...
# 21        57874  57879         Spring's Vitality Home , Spring's Vitality
# 22        57875  57879                        Beijing Metro Stands' View,
# 23        57876  57879           Grand Slam Series edible oil, Grand Slam
# 24        57877  57879               Embry Swimwear, Great days of summer
# 25        57878  57879             Beijing Spiritual Civilization Office,
# 26        57880  57879                             Beijing Metro Hallway,
# 27        57885  57879  Beijing Blood Donation, Beijing Office of Bloo...
# 28        57886  57879                                      China Soccer,
# 29        57888  57879                                           Jing Xi,
# ...         ...    ...                                                ...
# 4492      43574  43568                               Hawdii Sauce, Hawdii
# 4493      43576  43568                        Musical , Tristan & Yseult.
# 4494      43577  43568                       Vitalon Water, Vitalon Water
# 4495      43578  43568                                 Sinnsi Oolong Tea,
# 4496      43579  43568                                     Wacoal, Wacoal
# 4497      43580  43568                  Giordano, Giordano: Simply Khakis
# 4498      43581  43568                             Biore Cosmetics, Biore
# 4499      43582  43568                                 Motorola, Motorola
# 4500      43583  43568  Taipei Subway - Taipei Rapid Transit Corporation,
# 4501      43585  43568                Vitalon Water, Vitalon Super Supau.
# 4502      43586  43568                                    Jingwen School,
# 4503      43591  43568            Chinatrust Commercial Bank, Chinatrust.
# 4504      43593  43568  Cotton USA. CCI Cotton Council International, ...
# 4505      43595  43568                      Pickwick, Pickwick Finest Tea
# 4506      43597  43568             tcb-bank.com.tw , www.tcb-bank.com.tw.
# 4507      43599  43568                                Shiseido, Shisheido
# 4508      43605  43568                                   Public Campaign,
# 4509      43606  43568                                    Sony, Sony Wega
# 4510      43608  43568   Uni-President Pro Sweat Drink , Pro Sweat. Play.
# 4511      43609  43568                                     Konica, Konica
# 4512      43610  43568                                 Taipei Green Park,
# 4513      43612  43568                                       Lanew Shoe ,
# 4514      43613  43568                                         IMEI Food,
# 4515      43614  43568  ViewSonic, ViewSonic: The Display Technology C...
# 4516      43615  43568  Union Bank of Taiwan  , Union Bank of Taiwan C...
# 4517      43616  43568                            SK-II Cosmetics , SK-II
# 4518      43620  43568                   Audrey Bra , Audrey. Growing up.
# 4519      43621  43568                             TRTC MRT Picture, TRTC
# 4520      43625  43568                                    Navy Recruits ,
# 4521      43627  43568                                         Elle, Elle
#
#                                                    link
# 0     https://scholarship.rice.edu/handle/1911/57879...
# 1     https://scholarship.rice.edu/handle/1911/57904...
# 2     https://scholarship.rice.edu/handle/1911/57914...
# 3     https://scholarship.rice.edu/handle/1911/57934...
# 4     https://scholarship.rice.edu/handle/1911/57935...
# 5     https://scholarship.rice.edu/handle/1911/57943...
# 6     https://scholarship.rice.edu/handle/1911/57946...
# 7     https://scholarship.rice.edu/handle/1911/57947...
# 8     https://scholarship.rice.edu/handle/1911/57949...
# 9     https://scholarship.rice.edu/handle/1911/57954...
# 10    https://scholarship.rice.edu/handle/1911/57956...
# 11    https://scholarship.rice.edu/handle/1911/57957...
# 12    https://scholarship.rice.edu/handle/1911/57959...
# 13    https://scholarship.rice.edu/handle/1911/57961...
# 14    https://scholarship.rice.edu/handle/1911/57858...
# 15    https://scholarship.rice.edu/handle/1911/57859...
# 16    https://scholarship.rice.edu/handle/1911/57863...
# 17    https://scholarship.rice.edu/handle/1911/57865...
# 18    https://scholarship.rice.edu/handle/1911/57868...
# 19    https://scholarship.rice.edu/handle/1911/57871...
# 20    https://scholarship.rice.edu/handle/1911/57872...
# 21    https://scholarship.rice.edu/handle/1911/57874...
# 22    https://scholarship.rice.edu/handle/1911/57875...
# 23    https://scholarship.rice.edu/handle/1911/57876...
# 24    https://scholarship.rice.edu/handle/1911/57877...
# 25    https://scholarship.rice.edu/handle/1911/57878...
# 26    https://scholarship.rice.edu/handle/1911/57880...
# 27    https://scholarship.rice.edu/handle/1911/57885...
# 28    https://scholarship.rice.edu/handle/1911/57886...
# 29    https://scholarship.rice.edu/handle/1911/57888...
# ...                                                 ...
# 4492  https://scholarship.rice.edu/handle/1911/43574...
# 4493  https://scholarship.rice.edu/handle/1911/43576...
# 4494  https://scholarship.rice.edu/handle/1911/43577...
# 4495  https://scholarship.rice.edu/handle/1911/43578...
# 4496  https://scholarship.rice.edu/handle/1911/43579...
# 4497  https://scholarship.rice.edu/handle/1911/43580...
# 4498  https://scholarship.rice.edu/handle/1911/43581...
# 4499  https://scholarship.rice.edu/handle/1911/43582...
# 4500  https://scholarship.rice.edu/handle/1911/43583...
# 4501  https://scholarship.rice.edu/handle/1911/43585...
# 4502  https://scholarship.rice.edu/handle/1911/43586...
# 4503  https://scholarship.rice.edu/handle/1911/43591...
# 4504  https://scholarship.rice.edu/handle/1911/43593...
# 4505  https://scholarship.rice.edu/handle/1911/43595...
# 4506  https://scholarship.rice.edu/handle/1911/43597...
# 4507  https://scholarship.rice.edu/handle/1911/43599...
# 4508  https://scholarship.rice.edu/handle/1911/43605...
# 4509  https://scholarship.rice.edu/handle/1911/43606...
# 4510  https://scholarship.rice.edu/handle/1911/43608...
# 4511  https://scholarship.rice.edu/handle/1911/43609...
# 4512  https://scholarship.rice.edu/handle/1911/43610...
# 4513  https://scholarship.rice.edu/handle/1911/43612...
# 4514  https://scholarship.rice.edu/handle/1911/43613...
# 4515  https://scholarship.rice.edu/handle/1911/43614...
# 4516  https://scholarship.rice.edu/handle/1911/43615...
# 4517  https://scholarship.rice.edu/handle/1911/43616...
# 4518  https://scholarship.rice.edu/handle/1911/43620...
# 4519  https://scholarship.rice.edu/handle/1911/43621...
# 4520  https://scholarship.rice.edu/handle/1911/43625...
# 4521  https://scholarship.rice.edu/handle/1911/43627...
#
# [4522 rows x 4 columns]

# %% [markdown]
# Step 4: Query each item record to find all associated files, and for each file, extract how many views it has.

# %%
allrecords = pd.DataFrame({"itemhandle": [], "filename":[], "views": []})

for idx, row in allitems.iterrows():
    url = row['link']
    r = requests.get(url)
    page = r.text
    soup = bs(page,'html.parser')
   
    res = soup.find_all('table', {'id':"aspect_statistics_StatisticsTransformer_table_list-table"})
    headings = soup.find_all('h3', class_='ds-table-head')
   
    labels = []
    data = []
    handles = []
    
    index = 0
   
    for heading in headings:
        if heading.string == 'File Visits':
            record = res[index]
            labels.extend(list(map(lambda rec: rec.string, record.find_all('td', class_='labelcell'))))
            data.extend(list(map(lambda rec: rec.string, record.find_all('td', class_='datacell'))))
            handles.extend(list(map(lambda rec: row['handle'], record.find_all('td', class_='datacell'))))
        index += 1
       
    itemfiles = pd.DataFrame({'itemhandle': handles, 'filename': labels, 'views': data})
    allrecords = pd.concat([allrecords, itemfiles], ignore_index=True)
    
allrecords
# Out:
#       itemhandle                              filename views
# 0          57879                                587293    69
# 1          57879      putiancellphonea02b1.jpg(legacy)    66
# 2          57879      putiancellphonea02b2.jpg(legacy)    50
# 3          57879      putiancellphonea02b3.jpg(legacy)    49
# 4          57879  putiancellphonea02b2.jpg.jpg(legacy)    29
# 5          57879                                587291    27
# 6          57879              putiancellphonea02b1.jpg    18
# 7          57879              putiancellphonea02b3.jpg     3
# 8          57879              putiancellphonea02b2.jpg     2
# 9          57879                                587412    91
# 10         57879          motorolacelld02b.jpg(legacy)    44
# 11         57879                  motorolacelld02b.jpg    17
# 12         57879    guotongsecuritiesa01b1.jpg(legacy)    54
# 13         57879                                587441    49
# 14         57879    guotongsecuritiesa01b4.jpg(legacy)    46
# 15         57879    guotongsecuritiesa01b7.jpg(legacy)    45
# 16         57879    guotongsecuritiesa01b3.jpg(legacy)    45
# 17         57879    guotongsecuritiesa01b8.jpg(legacy)    45
# 18         57879    guotongsecuritiesa01b5.jpg(legacy)    42
# 19         57879    guotongsecuritiesa01b2.jpg(legacy)    39
# 20         57879    guotongsecuritiesa01b6.jpg(legacy)    38
# 21         57879            guotongsecuritiesa01b7.jpg    20
# 22         57879         olympuscameraa98b.JPG(legacy)    55
# 23         57879                                587487    48
# 24         57879                 olympuscameraa98b.JPG    17
# 25         57879                                587489   118
# 26         57879     colgatetoothbrusha03b.jpg(legacy)    70
# 27         57879             colgatetoothbrusha03b.jpg    20
# 28         57879                                587466   101
# 29         57879          cadburycandya02b.jpg(legacy)    73
# ...          ...                                   ...   ...
# 17638      43568                  TA6EFA~1.JPG(legacy)    67
# 17639      43568                                587973    56
# 17640      43568                          TA6EFA~1.JPG    18
# 17641      43568             lanewshoee03t.jpg(legacy)    53
# 17642      43568                                587992    32
# 17643      43568                     lanewshoee03t.jpg    19
# 17644      43568              imeifooda01t.jpg(legacy)    63
# 17645      43568                                587995    52
# 17646      43568                      imeifooda01t.jpg    23
# 17647      43568         viewsonictecha99t.jpg(legacy)    58
# 17648      43568                                587996    26
# 17649      43568                 viewsonictecha99t.jpg    20
# 17650      43568             unionbankb01t.jpg(legacy)   115
# 17651      43568                     unionbankb01t.jpg    93
# 17652      43568                                587997    48
# 17653      43568          sk2cosmeticsa02t.JPG(legacy)    40
# 17654      43568                                587994    30
# 17655      43568                  sk2cosmeticsa02t.JPG    19
# 17656      43568             audreybrab00t.jpg(legacy)    68
# 17657      43568                                588001    61
# 17658      43568                     audreybrab00t.jpg    27
# 17659      43568        trtcmrtpictureb03t.jpg(legacy)    52
# 17660      43568                                588002    52
# 17661      43568                trtcmrtpictureb03t.jpg    18
# 17662      43568                                588006  1276
# 17663      43568           navyrecruita00t.jpg(legacy)   144
# 17664      43568                   navyrecruita00t.jpg    19
# 17665      43568                                588008  1278
# 17666      43568           ellefashionb99t.jpg(legacy)   126
# 17667      43568                   ellefashionb99t.jpg    21
#
# [17668 rows x 3 columns]

# %% [markdown]
# Step 5: Merge the tables we have created to produce a final dataframe with only File Name, Views, and Collection Name as columns.

# %%
final = allrecords.merge(allitems.merge(allcollections, on='handle'),on='itemhandle')
final = final[['filename', 'views', 'collectionname']]
final['views'] = final.views.astype(int)
final
# Out:
#                                    filename  views collectionname
# 0                                    587293     69        Beijing
# 1          putiancellphonea02b1.jpg(legacy)     66        Beijing
# 2          putiancellphonea02b2.jpg(legacy)     50        Beijing
# 3          putiancellphonea02b3.jpg(legacy)     49        Beijing
# 4      putiancellphonea02b2.jpg.jpg(legacy)     29        Beijing
# 5                                    587291     27        Beijing
# 6                  putiancellphonea02b1.jpg     18        Beijing
# 7                  putiancellphonea02b3.jpg      3        Beijing
# 8                  putiancellphonea02b2.jpg      2        Beijing
# 9                                    587412     91        Beijing
# 10             motorolacelld02b.jpg(legacy)     44        Beijing
# 11                     motorolacelld02b.jpg     17        Beijing
# 12       guotongsecuritiesa01b1.jpg(legacy)     54        Beijing
# 13                                   587441     49        Beijing
# 14       guotongsecuritiesa01b4.jpg(legacy)     46        Beijing
# 15       guotongsecuritiesa01b7.jpg(legacy)     45        Beijing
# 16       guotongsecuritiesa01b3.jpg(legacy)     45        Beijing
# 17       guotongsecuritiesa01b8.jpg(legacy)     45        Beijing
# 18       guotongsecuritiesa01b5.jpg(legacy)     42        Beijing
# 19       guotongsecuritiesa01b2.jpg(legacy)     39        Beijing
# 20       guotongsecuritiesa01b6.jpg(legacy)     38        Beijing
# 21               guotongsecuritiesa01b7.jpg     20        Beijing
# 22            olympuscameraa98b.JPG(legacy)     55        Beijing
# 23                                   587487     48        Beijing
# 24                    olympuscameraa98b.JPG     17        Beijing
# 25                                   587489    118        Beijing
# 26        colgatetoothbrusha03b.jpg(legacy)     70        Beijing
# 27                colgatetoothbrusha03b.jpg     20        Beijing
# 28                                   587466    101        Beijing
# 29             cadburycandya02b.jpg(legacy)     73        Beijing
# ...                                     ...    ...            ...
# 17638                  TA6EFA~1.JPG(legacy)     67         Taipei
# 17639                                587973     56         Taipei
# 17640                          TA6EFA~1.JPG     18         Taipei
# 17641             lanewshoee03t.jpg(legacy)     53         Taipei
# 17642                                587992     32         Taipei
# 17643                     lanewshoee03t.jpg     19         Taipei
# 17644              imeifooda01t.jpg(legacy)     63         Taipei
# 17645                                587995     52         Taipei
# 17646                      imeifooda01t.jpg     23         Taipei
# 17647         viewsonictecha99t.jpg(legacy)     58         Taipei
# 17648                                587996     26         Taipei
# 17649                 viewsonictecha99t.jpg     20         Taipei
# 17650             unionbankb01t.jpg(legacy)    115         Taipei
# 17651                     unionbankb01t.jpg     93         Taipei
# 17652                                587997     48         Taipei
# 17653          sk2cosmeticsa02t.JPG(legacy)     40         Taipei
# 17654                                587994     30         Taipei
# 17655                  sk2cosmeticsa02t.JPG     19         Taipei
# 17656             audreybrab00t.jpg(legacy)     68         Taipei
# 17657                                588001     61         Taipei
# 17658                     audreybrab00t.jpg     27         Taipei
# 17659        trtcmrtpictureb03t.jpg(legacy)     52         Taipei
# 17660                                588002     52         Taipei
# 17661                trtcmrtpictureb03t.jpg     18         Taipei
# 17662                                588006   1276         Taipei
# 17663           navyrecruita00t.jpg(legacy)    144         Taipei
# 17664                   navyrecruita00t.jpg     19         Taipei
# 17665                                588008   1278         Taipei
# 17666           ellefashionb99t.jpg(legacy)    126         Taipei
# 17667                   ellefashionb99t.jpg     21         Taipei
#
# [17668 rows x 3 columns]

# %% [markdown]
# Step 6: Group by collection name and aggregate the number of views for all files in each community.

# %%
final.groupby('collectionname').filename.count()
# Out:
# collectionname
# Beijing      4730
# Hongkong     1755
# Kaoshiung     171
# Shanghai     4957
# Singapore    1965
# Taipei       4090
# Name: filename, dtype: int64

# %%
final.groupby('collectionname').views.sum()
# Out:
# collectionname
# Beijing      249143
# Hongkong     113365
# Kaoshiung      7800
# Shanghai     264322
# Singapore    161815
# Taipei       191555
# Name: views, dtype: int64
